# %% [markdown]
# ## using f as control parameter and v as order parameter, we see phase transition
#
# ![phase transition.png](attachment:f23b7a2b-942d-407d-b836-36ba537b4135.png)

# %% [markdown]
# ##
