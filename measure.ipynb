# %%
from multiprocessing import Process, Queue, current_process
from RTP_simul import simulate
import numpy as np
 
import os   
from multiprocessing import Process   

def simulproc(f): 
    print(f)
    simulate(20000,300,30,1,f,1,10000,10000,f)
if __name__ == '__main__': 
    numbers =  np.linspace(0.1,1,10)
    procs = []   
    
    for index, number in enumerate(numbers): 
        proc = Process(target=simulproc, args=(number,)) 
        procs.append(proc) 
        proc.start()   
        
    for proc in procs:
        proc.join()
# Out:
# 0.1
# RTP model initialized0.300000000000000040.2
#
# RTP model initialized
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 0.4RTP model initialized
#
# 0.5
#   0%|          | 11/10000 [00:00<01:32, 107.71it/s]
# 0.6RTP model initialized
#   0%|          | 0/10000 [00:00<?, ?it/s]
# RTP model initialized0.7000000000000001
#   0%|          | 18/10000 [00:00<01:55, 86.13it/s]
# 0.8
#
# RTP model initialized
#   0%|          | 29/10000 [00:00<01:48, 92.06it/s]
# 0.9
#   0%|          | 10/10000 [00:00<02:59, 55.69it/s]
# RTP model initializedRTP model initialized
#   0%|          | 4/10000 [00:00<06:04, 27.41it/s]
# 1.0
# RTP model initialized
# ...
#   0%|          | 0/10000 [00:00<?, ?it/s]6.78it/s]
# RTP model initialized
# ...
#   0%|          | 39/10000 [00:01<06:37, 25.03it/s]Process Process-10:
#
#
# Process Process-9:
# Process Process-4:
#   1%|          | 59/10000 [00:01<05:18, 31.22it/s]
#
# Traceback (most recent call last):
# ...

# %%
from RTP_simul import RTP_lab
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import trange

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_1 = pd.read_csv('10000ptcl16L300.csv',index_col=0)
# Out:
# /home/siksik/anaconda3/envs/siksik/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
groups =data_1.groupby('muFu')

# %%
fig, ax = plt.subplots()

for name, group in groups:

    if name>0.0:
        print(name)
        plt.plot(group.simul_iter+1, 

                group.c_one, 

                marker='o', 

                linestyle='',

                label=name)


#         data = group.c_one.to_numpy().reshape(-1,1)
#         one = np.average(data,axis=1)
#         one_r = np.average(np.abs(data),axis=1)
#         two_r = np.average(data**2,axis=1)-np.average(np.abs(data),axis=1)**2
#         binder = 1-np.average(data**4,axis=1)/(3*np.average(data**2,axis=1)**2)
        
#         plt.plot(

#                 two_r, 

#                 marker='o', 

#                 linestyle='',

#                 label=name)



#        plt.hist(one,bins=50)

    

#ax.legend(fontsize=8, loc='lower right') # legend position

        plt.title('Scatter Plot', fontsize=20)

        plt.xlabel('time', fontsize=14)

#plt.xlim([0,300])
        plt.ylabel('binder cumulant', fontsize=14)
        #plt.legend()

        plt.show()
# Out:
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.55
# 0.6
# 0.6499999999999999
# 0.7
# 0.75
# 0.8
# 0.85

# %%
f1,f2,f3,f4,f5,f6, f0 = np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0)
bind1,bind2,bind3,bind4,bind5,bind6, bind0 =  np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0)
two1,two2,two3,two4,two5,two6, two0 =  np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0)
one1,one2,one3,one4,one5,one6, one0 =  np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0)


"""
for key,group in groups1:
    f1 = np.append(f1, key)
    bind1 = np.append(bind1,group.mean()['binder'])
    two1 = np.append(two1,group.mean()['two_r'])
    one1 = np.append(one1,group.mean()['one_r'])
    
for key,group in groups2:
    f2 = np.append(f2, key)
    bind2 = np.append(bind2,group.mean()['binder'])
    two2 = np.append(two2,group.mean()['two_r'])
    one2 = np.append(one2,group.mean()['one_r'])
    
    """
for key,group in groups3:
    f3 = np.append(f3, key)
    bind3 = np.append(bind3,group.mean()['binder'])
    two3 = np.append(two3,group.mean()['two_r'])
    one3 = np.append(one3,group.mean()['one_r'])
    
    """
for key,group in groups4:
    f4 = np.append(f4, key)
    bind4 = np.append(bind4,group.mean()['binder'])
    two4 = np.append(two4,group.mean()['two_r'])
    one4 = np.append(one4,group.mean()['one_r'])
    
for key,group in groups5:
    f5 = np.append(f5, key)
    bind5 = np.append(bind5,group.mean()['binder'])
    two5 = np.append(two5,group.mean()['two_r'])
    one5 = np.append(one5,group.mean()['one_r'])
    
    
for key,group in groups6:
    f6 = np.append(f6, key)
    bind6 = np.append(bind6,group.mean()['binder'])
    two6 = np.append(two6,group.mean()['two_r'])
    one6 = np.append(one6,group.mean()['one_r'])
    
    
for key,group in groups0:
    f0 = np.append(f0, key)
    bind0 = np.append(bind0,group.mean()['binder'])
    two0 = np.append(two0,group.mean()['two_r'])
    one0 = np.append(one0,group.mean()['one_r'])
    """

# %%
data_1 = pd.read_csv('10000ptcl16L300.csv',index_col=0)
data_2 = pd.read_csv('20000ptcl16L300.csv',index_col=0)
data_3 = pd.read_csv('40000ptcl16L300.csv',index_col=0)
data_4 = pd.read_csv('80000ptcl16L300.csv',index_col=0)
#data_5 = pd.read_csv('160000ptcl8L300.csv',index_col=0)

# %%
groups1 =data_1[data_1['simul_iter']>1000].groupby('muFu') 
groups2 =data_2[data_2['simul_iter']>1000].groupby('muFu') 
groups3 =data_3[data_3['simul_iter']>1000].groupby('muFu') 
groups4 =data_4[data_4['simul_iter']>1000].groupby('muFu') 
#groups5 =data_5[data_5['simul_iter']>1000].groupby('muFu')

# %%
f1,f2,f3,f4,f5,f6, f0 = np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0)
bind1,bind2,bind3,bind4,bind5,bind6, bind0 =  np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0)
two1,two2,two3,two4,two5,two6, two0 =  np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0)
one1,one2,one3,one4,one5,one6, one0 =  np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0),np.empty(0)

measuring = 'velocity'
# measuring = 'current'

if measuring =='current':
    m_one = 'c_one'
    m_one_r = 'c_one_r'
    m_two = 'c_two'
    m_four = 'c_four'
else:
    m_one = 'one'
    m_one_r = 'one_r'
    m_two = 'two'
    m_four = 'four'    
        



for key,group in groups1:
    one = group.mean()[m_one]
    one_r = group.mean()[m_one_r]
    two = group.mean()[m_two]
    two_r = two-one_r**2
    four = group.mean()[m_four]
    binder = 1-four/(3*two**2)
    
    
    f1 = np.append(f1, key)
    bind1 = np.append(bind1,binder)
    two1 = np.append(two1,two_r)
    one1 = np.append(one1,one_r)
    
    
for key,group in groups2:
    one = group.mean()[m_one]
    one_r = group.mean()[m_one_r]
    two = group.mean()[m_two]
    two_r = two-one_r**2
    four = group.mean()[m_four]
    binder = 1-four/(3*two**2)
    
    
    f2 = np.append(f2, key)
    bind2 = np.append(bind2,binder)
    two2 = np.append(two2,two_r)
    one2 = np.append(one2,one_r)
    
for key,group in groups3:
    one = group.mean()[m_one]
    one_r = group.mean()[m_one_r]
    two = group.mean()[m_two]
    two_r = two-one_r**2
    four = group.mean()[m_four]
    binder = 1-four/(3*two**2)
    
    
    f3 = np.append(f3, key)
    bind3 = np.append(bind3,binder)
    two3 = np.append(two3,two_r)
    one4 = np.append(one4,one_r)
    
for key,group in groups4:
    one = group.mean()[m_one]
    one_r = group.mean()[m_one_r]
    two = group.mean()[m_two]
    two_r = two-one_r**2
    four = group.mean()[m_four]
    binder = 1-four/(3*two**2)
    
    
    f4 = np.append(f4, key)
    bind4 = np.append(bind4,binder)
    two4 = np.append(two4,two_r)
    one4 = np.append(one4,one_r)
    
# for key,group in groups5:
#     one = group.mean()['c_one']
#     one_r = group.mean()['c_one_r']
#     two = group.mean()['c_two']
#     two_r = two-one_r**2
#     four = group.mean()['c_four']
#     binder = 1-four/(3*two**2)
    
    
#     f5 = np.append(f5, key)
#     bind5 = np.append(bind5,binder)
#     two5 = np.append(two5,two_r)
#     one5 = np.append(one5,one_r)

# %%
plt.scatter(f1,bind1, label='10k')
plt.plot(f1,bind1)

plt.scatter(f2,bind2, label='20k')
plt.plot(f2,bind2)


plt.scatter(f3,bind3, label='40k')
plt.plot(f3,bind3)

plt.scatter(f4,bind4, label='80k')
plt.plot(f4,bind4)

# plt.scatter(f5,bind5, label='160k')
# plt.plot(f5,bind5)


    
plt.xlabel('muF/u', fontsize='15')
plt.ylabel('Binder cumulant', fontsize='15')

#plt.xlim([0.0,0.7])
#plt.ylim([-0.1,0.7])
plt.legend(fontsize='15')
plt.grid()

plt.show()


plt.scatter(f1,two1/10000, label='10k')
plt.plot(f1,two1/10000)

plt.scatter(f2,two2/20000, label='20k')
plt.plot(f2,two2/20000)


plt.scatter(f3,two3/40000, label='40k')
plt.plot(f3,two3/40000)

plt.scatter(f4,two4/80000, label='80k')
plt.plot(f4,two4/80000)

# plt.scatter(f5,two5/160000, label='80k')
# plt.plot(f5,two5/160000)


    
plt.xlabel('muF/u', fontsize='15')
plt.yscale('log')
plt.ylabel('2nd cumulant', fontsize='15')

#plt.xlim([0.0,0.7])
#plt.ylim([-0.1,0.7])
plt.legend(fontsize='15')
plt.grid()

plt.show()

# %%
"""
plt.scatter(f1,bind1, label='25k')
plt.plot(f1,bind1)

plt.scatter(f2,bind2, label='50k')
plt.plot(f2,bind2)
"""
plt.scatter(f3,bind3, label='100k')
plt.plot(f3,bind3)
"""
plt.scatter(f4,bind4, label='200k')
plt.plot(f4,bind4)


plt.scatter(f5,bind5, label='400k')
plt.plot(f5,bind5)

plt.scatter(f6,bind6, label='800k')
plt.plot(f6,bind6)
"""
#plt.plot([0.23035,0.23035],[-0.1,0.8],color='r')

    
plt.xlabel('muF/u', fontsize='15')
plt.ylabel('Binder Cumulant', fontsize='15')

#plt.xlim([0.223,0.238])
plt.ylim([-0.1,0.7])
plt.legend(fontsize='15')
plt.grid()

plt.show()

# %%
"""
plt.scatter(f1,two1, label='25k')
plt.plot(f1,two1)

plt.scatter(f2,two2, label='50k')
plt.plot(f2,two2)
"""
plt.scatter(f3,two3, label='100k')
plt.plot(f3,two3)
"""
plt.scatter(f4,two4, label='200k')
plt.plot(f4,two4)


plt.scatter(f5,two5, label='400k')
plt.plot(f5,two5)

plt.scatter(f6,two6, label='800k')
plt.plot(f6,two6)
"""
#plt.plot([0.23035,0.23035],[-0.1,100000],color='r')

    
plt.xlabel('muF/u', fontsize='15')
plt.ylabel('2nd Cumulant', fontsize='15')

#plt.xlim([0.223,0.238])
#plt.ylim([1,100000])
plt.legend(fontsize='15')
plt.grid()
plt.yscale('log')

plt.show()

# %%
#groups1 =data_time1.groupby('muFu')
#groups2 =data_time2.groupby('muFu')
groups3 =data_time3.groupby('muFu')
#groups4 =data_time4.groupby('muFu')
#groups5 =data_time5.groupby('muFu')

#groups0 =data_time0.groupby('muFu')

# %%
fig, ax = plt.subplots()

for name, group in groups3:

    if name>0.0:
        ax.plot(group.simul_iter+1, 

                group.one_r, 

                marker='o', 

                linestyle='',

                label=name)

    

#ax.legend(fontsize=8, loc='lower right') # legend position

plt.title('Scatter Plot', fontsize=20)

plt.xlabel('time', fontsize=14)

plt.xlim([0,300])
plt.ylabel('binder cumulant', fontsize=14)
plt.legend()

plt.show()

# %%
ptcl = 100000
number_X = 100

import os

for name, group in groups3:
    try:
        f=name
        state = os.getcwd()+'/data/'+str(ptcl)+str(number_X)+"f"+str(f)+'.npz'
        load = np.load(state)
        print(f)
        plt.hist(load['v']/load['u'],bins=30)
        #plt.xlim([-5,5])
        plt.show()
    except:
        continue
# Out:
# 0.3
# 0.31
# 0.75
# 0.76
